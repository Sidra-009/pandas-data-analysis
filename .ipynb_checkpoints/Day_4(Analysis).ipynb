# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv('DataScience_salaries_2024.csv')

# %%
data.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 0       2021               MI              FT                  Data Scientist
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  30400000             CLP          40038                 CL           100
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
#
#   company_location company_size
# 0               CL            L
# 1               US            L
# 2               HU            L
# 3               JP            S
# 4               IN            L

# %%
mask=data['remote_ratio']==50
hu=data[mask]
hu.head()
# Out:
#    work_year experience_level employment_type                       job_title  \
# 1       2021               MI              FT                 BI Data Analyst
# 2       2020               MI              FT                  Data Scientist
# 3       2021               MI              FT                     ML Engineer
# 4       2022               SE              FT  Lead Machine Learning Engineer
# 5       2021               MI              FT                     ML Engineer
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 1  11000000             HUF          36259                 HU            50
# 2  11000000             HUF          35735                 HU            50
# 3   8500000             JPY          77364                 JP            50
# 4   7500000             INR          95386                 IN            50
# 5   7000000             JPY          63711                 JP            50
#
#   company_location company_size
# 1               US            L
# 2               HU            L
# 3               JP            S
# 4               IN            L
# 5               JP            S

# %%
hu.shape
# Out:
# (248, 11)

# %%
pt=hu.pivot_table(index='work_year',columns='job_title',values='salary',aggfunc='count')

# %%
pt
# Out:
# job_title  AI Developer  AI Engineer  AI Product Manager  \
# work_year
# 2020                NaN          NaN                 NaN
# 2021                NaN          NaN                 NaN
# 2022                NaN          NaN                 NaN
# 2023                3.0          1.0                 1.0
# 2024                1.0          1.0                 NaN
#
# job_title  AI Research Scientist  AI Scientist  Analytics Engineer  \
# work_year
# 2020                         NaN           1.0                 NaN
# 2021                         NaN           NaN                 NaN
# 2022                         NaN           1.0                 1.0
# 2023                         NaN           2.0                 NaN
# 2024                         1.0           NaN                 NaN
#
# job_title  Analytics Engineering Manager  Applied Data Scientist  \
# work_year
# 2020                                 NaN                     NaN
# 2021                                 NaN                     1.0
# 2022                                 NaN                     1.0
# 2023                                 1.0                     1.0
# 2024                                 NaN                     NaN
#
# job_title  Applied Machine Learning Scientist  Applied Scientist  ...  \
# work_year                                                         ...
# 2020                                      NaN                NaN  ...
# 2021                                      1.0                NaN  ...
# 2022                                      1.0                NaN  ...
# 2023                                      1.0                1.0  ...
# 2024                                      NaN                NaN  ...
#
# job_title  Marketing Data Engineer  Marketing Data Scientist  \
# work_year
# 2020                           NaN                       NaN
# 2021                           1.0                       NaN
# 2022                           NaN                       NaN
# 2023                           NaN                       1.0
# 2024                           NaN                       NaN
#
# job_title  Principal Machine Learning Engineer  Product Data Analyst  \
# work_year
# 2020                                       NaN                   NaN
# 2021                                       NaN                   NaN
# 2022                                       NaN                   NaN
# 2023                                       1.0                   1.0
# 2024                                       NaN                   NaN
#
# job_title  Research Engineer  Research Scientist  Software Data Engineer  \
# work_year
# 2020                     NaN                 1.0                     NaN
# 2021                     NaN                 6.0                     NaN
# 2022                     2.0                 3.0                     NaN
# 2023                     1.0                 2.0                     1.0
# 2024                     NaN                 NaN                     NaN
#
# job_title  Staff Data Analyst  Staff Data Scientist  \
# work_year
# 2020                      1.0                   1.0
# 2021                      NaN                   NaN
# 2022                      NaN                   NaN
# 2023                      NaN                   NaN
# 2024                      NaN                   NaN
#
# job_title  Staff Machine Learning Engineer
# work_year
# 2020                                   NaN
# 2021                                   1.0
# 2022                                   NaN
# 2023                                   NaN
# 2024                                   NaN
#
# [5 rows x 71 columns]

# %%
import seaborn as sns

# %%
sns.heatmap(pt)
# Out:
# <Axes: xlabel='job_title', ylabel='work_year'>

# %%
#correlation 
data.corr(numeric_only=True)
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.074329       0.090873     -0.204954
# salary         -0.074329  1.000000       0.128313      0.019249
# salary_in_usd   0.090873  0.128313       1.000000     -0.064829
# remote_ratio   -0.204954  0.019249      -0.064829      1.000000

# %%
sns.heatmap(data.corr(numeric_only=True))
# Out:
# <Axes: >

# %%
#remote cois(renaming cols names )

# %%
data.rename(columns={'company_location':'company_loc','employee_residence':'emp_residence'},inplace=True)

# %%
# set and reset index
data.set_index('job_title')
# Out:
#                                 experience_level employment_type    salary  \
# job_title
# Data Scientist                                MI              FT  30400000
# BI Data Analyst                               MI              FT  11000000
# Data Scientist                                MI              FT  11000000
# ML Engineer                                   MI              FT   8500000
# Lead Machine Learning Engineer                SE              FT   7500000
# ...                                          ...             ...       ...
# Business Intelligence Developer               MI              FT     15000
# Staff Data Analyst                            EX              FT     15000
# Machine Learning Developer                    EN              FT     15000
# Data Analyst                                  EN              FT     15000
# ML Engineer                                   EN              PT     14000
#
#                                 salary_currency  salary_in_usd emp_residence  \
# job_title
# Data Scientist                              CLP          40038            CL
# BI Data Analyst                             HUF          36259            HU
# Data Scientist                              HUF          35735            HU
# ML Engineer                                 JPY          77364            JP
# Lead Machine Learning Engineer              INR          95386            IN
# ...                                         ...            ...           ...
# Business Intelligence Developer             USD          15000            GH
# Staff Data Analyst                          USD          15000            NG
# Machine Learning Developer                  USD          15000            TH
# Data Analyst                                USD          15000            ID
# ML Engineer                                 EUR          15966            DE
#
#                                  remote_ratio company_loc company_size
# job_title
# Data Scientist                            100          CL            L
# BI Data Analyst                            50          US            L
# Data Scientist                             50          HU            L
# ML Engineer                                50          JP            S
# Lead Machine Learning Engineer             50          IN            L
# ...                                       ...         ...          ...
# Business Intelligence Developer           100          GH            M
# Staff Data Analyst                          0          CA            M
# Machine Learning Developer                100          TH            L
# Data Analyst                                0          ID            L
# ML Engineer                               100          DE            S
#
# [14838 rows x 9 columns]

# %%
data.reset_index()
# Out:
#        work_year experience_level employment_type  \
# 0           2021               MI              FT
# 1           2021               MI              FT
# 2           2020               MI              FT
# 3           2021               MI              FT
# 4           2022               SE              FT
# ...          ...              ...             ...
# 14833       2022               MI              FT
# 14834       2020               EX              FT
# 14835       2021               EN              FT
# 14836       2022               EN              FT
# 14837       2020               EN              PT
#
#                              job_title    salary salary_currency  \
# 0                       Data Scientist  30400000             CLP
# 1                      BI Data Analyst  11000000             HUF
# 2                       Data Scientist  11000000             HUF
# 3                          ML Engineer   8500000             JPY
# 4       Lead Machine Learning Engineer   7500000             INR
# ...                                ...       ...             ...
# 14833  Business Intelligence Developer     15000             USD
# 14834               Staff Data Analyst     15000             USD
# 14835       Machine Learning Developer     15000             USD
# 14836                     Data Analyst     15000             USD
# 14837                      ML Engineer     14000             EUR
#
#        salary_in_usd emp_residence  remote_ratio company_loc company_size
# 0              40038            CL           100          CL            L
# 1              36259            HU            50          US            L
# 2              35735            HU            50          HU            L
# 3              77364            JP            50          JP            S
# 4              95386            IN            50          IN            L
# ...              ...           ...           ...         ...          ...
# 14833          15000            GH           100          GH            M
# 14834          15000            NG             0          CA            M
# 14835          15000            TH           100          TH            L
# 14836          15000            ID             0          ID            L
# 14837          15966            DE           100          DE            S
#
# [14838 rows x 11 columns]

# %%
data['job_title'].value_counts().reset_index()
# Out:
#                            job_title  count
# 0                      Data Engineer   3162
# 1                     Data Scientist   3015
# 2                       Data Analyst   2189
# 3          Machine Learning Engineer   1542
# 4                 Research Scientist    475
# ..                               ...    ...
# 148         Deep Learning Researcher      1
# 149               Big Data Developer      1
# 150               AWS Data Architect      1
# 151  Staff Machine Learning Engineer      1
# 152                 CRM Data Analyst      1
#
# [153 rows x 2 columns]
