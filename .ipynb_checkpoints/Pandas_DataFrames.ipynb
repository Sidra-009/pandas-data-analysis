# %%
import pandas as pd

# %%
food=pd.read_csv('food_order.csv')

# %%
food.head()
# Out:
#    Order ID     Customer Name Food Item Category  Quantity  Price  \
# 0      2268     Mary Vega DDS     Pasta     Main         5  16.52
# 1      3082     Brandon Myers   Brownie  Dessert         4  17.27
# 2      3160    Margaret Wells     Pasta     Main         1   3.37
# 3      1272  Michael Matthews     Pasta     Main         5   2.20
# 4      9447   Connor Williams      Soup  Starter         1  12.23
#
#    Payment Method           Order Time
# 0            Cash  2025-02-02 14:28:41
# 1      Debit Card  2025-06-08 10:57:47
# 2     Credit Card  2025-03-04 07:41:41
# 3  Online Payment  2025-05-15 12:43:45
# 4            Cash  2025-03-15 14:25:56

# %%
data.shape
# Out:
# (1615, 12)

# %%
# pivot table(picks one data folds in mutiple tables and give us view)
food.pivot_table(index=['Order ID','Customer Name'],columns=['Food Item','Payment Method'],values='Price',aggfunc='mean')
# Out:
# Food Item                 Brownie                                        \
# Payment Method               Cash Credit Card Debit Card Online Payment
# Order ID Customer Name
# 1055     David Gutierrez      NaN         NaN        NaN            NaN
# 1057     Hannah Brown         NaN         NaN        NaN            NaN
# 1066     Melissa Duncan       NaN         NaN        NaN            NaN
# 1084     Eric Nguyen          NaN         NaN        NaN            NaN
# 1088     Carol Lynch          NaN         NaN        NaN            NaN
# ...                           ...         ...        ...            ...
# 9927     Gary Phillips        NaN         NaN        NaN            NaN
# 9936     Debbie Castillo      NaN         NaN        NaN            NaN
# 9963     Jonathan Turner      NaN         NaN        NaN            NaN
# 9969     Monica Hill          NaN         NaN        NaN            NaN
# 9997     Elizabeth Hunter     NaN         NaN        NaN            NaN
#
# ...
